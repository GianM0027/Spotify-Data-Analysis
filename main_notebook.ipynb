# %% [markdown]
# # Imports and Data Extraction

# %%
# %load_ext autoreload
# %autoreload 2

from utilities import *
from constants import *
from data_managers.account_data_manager import AccountData
from data_managers.audio_history_manager import AudioHistory
from data_managers.video_history_manager import VideoHistory
import dotenv

dotenv.load_dotenv();

# %%
account_data, music_data, video_data = find_account_and_history_data(DATA_DIR)

account_data = AccountData(account_data)
music_data = AudioHistory(music_data)
video_data = VideoHistory(video_data)
# Out:
# All good Jimmynera! Your data has been extracted correctly. Here are all the files that Spotify provided:
#
# Your account data contains the following entries:
#  ['Follow', 'Identifiers', 'Identity', 'Inferences', 'Marquee', 'Payments', 'Playlist1', 'PlaylistInABottle', 'PodcastInteractivityVotedPollOption', 'SearchQueries', 'StreamingHistory_music_0', 'StreamingHistory_music_1', 'StreamingHistory_music_2', 'StreamingHistory_podcast_0', 'Userdata', 'Wrapped2024', 'YourLibrary']
#
# Your history data contains the following entries:
#  ['Streaming_History_Audio_2021-2022_0', 'Streaming_History_Audio_2022-2023_3', 'Streaming_History_Audio_2022_1', 'Streaming_History_Audio_2022_2', 'Streaming_History_Audio_2023-2024_4', 'Streaming_History_Audio_2024-2025_6', 'Streaming_History_Audio_2024_5', 'Streaming_History_Audio_2025_7', 'Streaming_History_Video_2021-2025']

# %%
account_data.print_account_info()
# Out:
# ##################################################
# Hello Jimmynera! Here are some info about you and your account
#  - You created this account on 22-04-2018.
#  - Your birthday is on 30-10-2000.
#
# ##################################################
# It looks like you created some playlists:
# - My 2024 Playlist in a Bottle 	-	 A musical time capsule from the past has been unsealed…!
# - Vroom vroom 	-	 Vroom vroom
# - Canzoncine 2.0
# - RoadToLaurea

# %%
music_data
# Out:
#               date      time                                         platform  \
# 0       2021-02-27  13:45:16  Android-tablet OS 10 API 29 (SAMSUNG, SM-T866N)
# 1       2021-02-27  13:45:20  Android-tablet OS 10 API 29 (SAMSUNG, SM-T866N)
# 2       2021-02-27  13:48:30  Android-tablet OS 10 API 29 (SAMSUNG, SM-T866N)
# 3       2021-02-27  13:51:47  Android-tablet OS 10 API 29 (SAMSUNG, SM-T866N)
# 4       2021-02-27  13:54:52  Android-tablet OS 10 API 29 (SAMSUNG, SM-T866N)
# ...            ...       ...                                              ...
# 114435  2025-08-17  14:39:45                                          windows
# 114436  2025-08-17  17:38:34                                          android
# 114437  2025-08-17  17:40:53                                          android
# 114438  2025-08-17  18:11:01                                          android
# 114439  2025-08-17  22:12:56                                          android
#
#         ms_played conn_country       ip_addr  \
# 0            6635           IT  93.67.61.205
# 1            3207           IT  93.67.61.205
# 2          190218           IT  93.67.61.205
# 3          196613           IT  93.67.61.205
# 4          184426           IT  93.67.61.205
# ...           ...          ...           ...
# 114435     207480           IT   5.91.108.30
# 114436      11911           IT   5.91.108.56
# 114437     138639           IT   5.91.108.56
# 114438      57238           IT    5.90.152.7
# 114439       9535           IT   5.90.146.28
#
#                                master_metadata_track_name  \
# 0       Choral de la Cantate "Jesus nahm zu sich die Z...
# 1                                 With You - Dexter Remix
# 2                                All We Got (feat. KIDDO)
# 3                                 With You - Dexter Remix
# 4                                          I Met Somebody
# ...                                                   ...
# 114435                       you’re all i ever dreamed of
# 114436                                          Strangers
# 114437                        Through The Eyes Of A Child
# 114438                                              Ghost
# 114439                                           good 4 u
#
#        master_metadata_album_artist_name  \
# 0                  Johann Sebastian Bach
# 1                                Kaskade
# 2                           Robin Schulz
# 3                                Kaskade
# 4                           John De Sohn
# ...                                  ...
# 114435                    Chelsea Cutler
# 114436                            Halsey
# 114437                            AURORA
# 114438                       Johnny Chay
# 114439                    Olivia Rodrigo
#
#              master_metadata_album_album_name  \
# 0                         Bach: Contemplation
# 1                      With You - The Remixes
# 2                    All We Got (feat. KIDDO)
# 3                      With You - The Remixes
# 4                              I Met Somebody
# ...                                       ...
# 114435                              Stellaria
# 114436              hopeless fountain kingdom
# 114437  All My Demons Greeting Me As A Friend
# 114438                                  Ghost
# 114439                                   SOUR
#
#                            spotify_track_uri  ... audiobook_uri  \
# 0       spotify:track:2gOTQW7UbZsGf2jyv4mUZ7  ...          None
# 1       spotify:track:1nwoWaqzB30bD4IPqRNuex  ...          None
# 2       spotify:track:1FP9s72rDYty6mfoOEYKnE  ...          None
# 3       spotify:track:1nwoWaqzB30bD4IPqRNuex  ...          None
# 4       spotify:track:4wFxu6EL2wjhCQ9qs1CeKi  ...          None
# ...                                      ...  ...           ...
# 114435  spotify:track:0ITVaSgOcMeLjUz9XkCoQj  ...          None
# 114436  spotify:track:6uW5fyyosEMBKfg2W1ye1l  ...          None
# 114437  spotify:track:6XFvsdR5sHHNy5dOcbz545  ...          None
# 114438  spotify:track:4UAEy7FFdCL3mmrjj3q3RI  ...          None
# 114439  spotify:track:4ZtFanR9U6ndgddUvNcjcG  ...          None
#
#        audiobook_chapter_uri audiobook_chapter_title reason_start reason_end  \
# 0                       None                    None      playbtn    endplay
# 1                       None                    None     clickrow    endplay
# 2                       None                    None     clickrow  trackdone
# 3                       None                    None    trackdone  trackdone
# 4                       None                    None    trackdone  trackdone
# ...                      ...                     ...          ...        ...
# 114435                  None                    None    trackdone  trackdone
# 114436                  None                    None       fwdbtn     fwdbtn
# 114437                  None                    None       fwdbtn     fwdbtn
# 114438                  None                    None       fwdbtn     logout
# 114439                  None                    None       fwdbtn     remote
#
#        shuffle skipped offline offline_timestamp  incognito_mode
# 0         True   False   False               NaN           False
# 1        False   False   False               NaN           False
# 2        False   False   False               NaN           False
# 3        False   False   False               NaN           False
# 4        False   False   False               NaN           False
# ...        ...     ...     ...               ...             ...
# 114435    True   False   False      1.755441e+09           False
# 114436   False    True   False      1.755452e+09           False
# 114437   False    True   False      1.755452e+09           False
# 114438   False   False   False      1.755452e+09           False
# 114439    True   False    True      1.755469e+09            True
#
# [114440 rows x 24 columns]

# %%
video_data
# Out:
#            date      time                                 platform  ms_played  \
# 0    2021-12-01  19:19:16  Android OS 11 API 30 (Xiaomi, M2101K9G)       5801
# 1    2022-11-30  15:23:47                                  android          0
# 2    2022-11-30  15:23:47                                  android       4929
# 3    2022-11-30  15:23:47                                  android       3822
# 4    2022-11-30  15:23:47                                  android          0
# ..          ...       ...                                      ...        ...
# 324  2025-08-17  21:29:12                                  android       2767
# 325  2025-08-17  21:29:15                                  android         41
# 326  2025-08-17  21:29:36                                  android       5142
# 327  2025-08-17  22:13:10                                  android          0
# 328  2025-08-17  22:15:42                                  android          0
#
#     conn_country        ip_addr  \
# 0             DE  141.70.61.148
# 1             IT   84.17.58.196
# 2             IT   84.17.58.196
# 3             IT   84.17.58.196
# 4             IT   84.17.58.196
# ..           ...            ...
# 324           IT     5.90.152.7
# 325           IT     5.90.152.7
# 326           IT     5.90.152.7
# 327           IT    5.90.146.28
# 328           IT    5.90.146.28
#
#                             master_metadata_track_name  \
# 0                                                 None
# 1                                     Hansu Sees Sunja
# 2                                         Good Feeling
# 3                                 Something to Someone
# 4                                            Your Body
# ..                                                 ...
# 324                                               None
# 325                                               None
# 326                                               None
# 327  Swan Song - From the Motion Picture "Alita: Ba...
# 328                                    Dangerous Woman
#
#     master_metadata_album_artist_name  \
# 0                                None
# 1                          Nico Muhly
# 2                              Duvall
# 3                      Dermot Kennedy
# 4                                DLMT
# ..                                ...
# 324                              None
# 325                              None
# 326                              None
# 327                          Dua Lipa
# 328                     Ariana Grande
#
#                       master_metadata_album_album_name  \
# 0                                                 None
# 1    Pachinko: Season 1 (Apple TV+ Original Series ...
# 2                                         Good Feeling
# 3                                 Something to Someone
# 4                                            Your Body
# ..                                                 ...
# 324                                               None
# 325                                               None
# 326                                               None
# 327                                          Swan Song
# 328                                    Dangerous Woman
#
#                         spotify_track_uri  ... audiobook_title audiobook_uri  \
# 0                                    None  ...            None          None
# 1    spotify:track:36U06R699jzn3RBSwVVwvb  ...            None          None
# 2    spotify:track:0TxR77PJYC8bHUiENFcpig  ...            None          None
# 3    spotify:track:2eWOo3ooHrVezj2pmapV8X  ...            None          None
# 4    spotify:track:4UV5qm4XHQETdXrVZjIsSU  ...            None          None
# ..                                    ...  ...             ...           ...
# 324                                  None  ...            None          None
# 325                                  None  ...            None          None
# 326                                  None  ...            None          None
# 327  spotify:track:2tAGfTgJYR9JScHL6J85Q8  ...            None          None
# 328  spotify:track:69ensumBYKonDtZyF9GScS  ...            None          None
#
#     audiobook_chapter_uri audiobook_chapter_title reason_start reason_end  \
# 0                    None                    None    trackdone  trackdone
# 1                    None                    None      unknown    endplay
# 2                    None                    None      unknown    endplay
# 3                    None                    None      unknown    endplay
# 4                    None                    None      unknown    endplay
# ..                    ...                     ...          ...        ...
# 324                  None                    None      unknown    endplay
# 325                  None                    None      unknown    endplay
# 326                  None                    None      unknown    endplay
# 327                  None                    None      unknown    endplay
# 328                  None                    None      unknown    endplay
#
#     shuffle skipped offline_timestamp  incognito_mode
# 0      True   False               NaN           False
# 1     False    True               NaN           False
# 2     False    True               NaN           False
# 3     False    True               NaN           False
# 4     False    True               NaN           False
# ..      ...     ...               ...             ...
# 324   False    True      1.755466e+09           False
# 325   False    True      1.755466e+09            True
# 326   False    True      1.755466e+09            True
# 327   False    True      1.755469e+09            True
# 328   False    True      1.755469e+09            True
#
# [329 rows x 23 columns]

# %% [markdown]
# ### How many listened songs?

# %%
start_date, end_date, days = music_data.listening_period()

tot_songs = len(music_data)
unique_songs = len(music_data.drop_duplicates(subset="master_metadata_track_name"))

print(f"Between {start_date} and {end_date} ({days} days) you listened to:")
print(f"- {tot_songs} songs (in total)")
print(f"- {unique_songs} different songs")
# Out:
# Between 2021-02-27 and 2025-08-17 (1632 days) you listened to:
# - 114440 songs (in total)
# - 14667 different songs

# %% [markdown]
# ### Top K songs by minutes played

# %%
K = 10  #change the value of this k in order to see less/more results

top_k_songs, tot_minutes = print_most_listened_to(music_data, k=K)

print(f"You listened to {tot_minutes} minutes of music. "
      f"\nThe following are your top {K} songs that you listen to the most:")
top_k_songs
# Out:
# You listened to 302387 minutes of music.
# The following are your top 10 songs that you listen to the most:
#                             Song        Author  minutes played
# 1                        Runaway        AURORA     1629.092633
# 2                 Buzzcut Season         Lorde     1294.679067
# 3                      The River        AURORA     1018.553817
# 4                           Team         Lorde     1017.538183
# 5               tomorrow tonight         Loote      808.994517
# 6                         Colors        Halsey      802.307550
# 7              Welcome Home, Son  Radical Face      798.208600
# 8   Hero (feat. Christina Perri)     Cash Cash      794.609317
# 9    Through The Eyes Of A Child        AURORA      786.993633
# 10                     Fractions  Juniper Vale      778.057233

# %% [markdown]
# ### Months and times of the day when you listened to the most music

# %%
music_data.plot_yearly_minutes()

# %%
music_data.plot_monthly_minutes(year=2025)
