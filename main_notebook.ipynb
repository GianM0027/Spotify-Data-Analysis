# %% [markdown]
# # Spotify Data Analyzer
#
# Welcome! This is my Spotify data analyzer—maybe a bit less convenient than an app with a fancy graphical interface, but it still gets the job done.
# Have fun!

# %% [markdown]
# ## Imports and Data Extraction

# %%
# %load_ext autoreload
# %autoreload 2

from utilities import *
from constants import *
from data_managers.account_data_manager import AccountData
from data_managers.audio_history_manager import AudioHistory
from data_managers.video_history_manager import VideoHistory
import dotenv

dotenv.load_dotenv();

# %%
account_data, music_data, video_data = find_account_and_history_data(DATA_DIR)

account_data = AccountData(account_data)
music_data = AudioHistory(music_data)
video_data = VideoHistory(video_data)
# Out:
# All good! Your data has been extracted correctly. Here are all the files that Spotify provided:
#
# Your account data contains the following entries:
#  []
#
# Your history data contains the following entries:
#  ['Streaming_History_Audio_2015-2017_0', 'Streaming_History_Audio_2017-2019_1', 'Streaming_History_Audio_2019-2021_2', 'Streaming_History_Audio_2021-2023_3', 'Streaming_History_Audio_2023-2024_4', 'Streaming_History_Audio_2024-2025_5', 'Streaming_History_Video_2018-2025']

# %%
account_data.print_account_info()
# Out:
# It looks like you did not load any account data :(

# %%
music_data
# Out:
#              date      time                                       platform  \
# 0      2015-06-01  19:31:26  Android OS 4.2.2 API 17 (HTC, HTC Desire 310)
# 1      2015-06-01  19:31:27  Android OS 4.2.2 API 17 (HTC, HTC Desire 310)
# 2      2015-06-01  19:31:28  Android OS 4.2.2 API 17 (HTC, HTC Desire 310)
# 3      2015-06-01  19:31:29  Android OS 4.2.2 API 17 (HTC, HTC Desire 310)
# 4      2015-06-01  19:31:30  Android OS 4.2.2 API 17 (HTC, HTC Desire 310)
# ...           ...       ...                                            ...
# 84956  2025-08-17  23:24:12                                        android
# 84957  2025-08-17  23:28:26                                        android
# 84958  2025-08-17  23:33:23                                        android
# 84959  2025-08-17  23:43:43                                        android
# 84960  2025-08-18  21:57:59                                        android
#
# ...

# %%
video_data
# Out:
#             date      time                                           platform  \
# 0     2018-11-09  15:20:49  Android-tablet OS  API 24 (HUAWEI, f4787d15af7...
# 1     2022-08-18  12:18:37             Android OS 12 API 31 (OnePlus, DN2103)
# 2     2022-09-10  09:09:08             Android OS 12 API 31 (OnePlus, DN2103)
# 3     2023-07-16  21:49:54                                            android
# 4     2023-07-16  21:49:55                                            android
# ...          ...       ...                                                ...
# 1578  2025-08-07  21:29:15                                            android
# 1579  2025-08-08  18:03:05                                            android
# 1580  2025-08-09  12:33:55                                            android
# 1581  2025-08-14  22:11:19                                            android
# 1582  2025-08-16  23:13:27                                            android
#
# ...

# %% [markdown]
# ## Some Listening Statistics

# %%
music_data.print_listening_stats()
# Out:
# Between 2015-06-01 and 2025-08-18 (3731 days) you listened to:
# - 84961 songs (in total)
# - 16099 different songs

# %% [markdown]
# ### Top songs by minutes played

# %%
top_k_songs, tot_minutes = music_data.print_most_listened_to(time_start=None, # datetime(2020, 1, 1) 
                                                             time_end=None)

print(f"You listened to {tot_minutes} minutes of music. ")
top_k_songs
# Out:
# You listened to 66696 minutes of music.
#                              Song                    Author  minutes played
# 0                      Apocalypse      Cigarettes After Sex      491.456217
# 1                         Le Onde          Ludovico Einaudi      236.546050
# 2                          Pistol      Cigarettes After Sex      207.145167
# 3                              K.      Cigarettes After Sex      200.393367
# 4       Midnight Train to Georgia  Gladys Knight & The Pips      188.009783
# ...                           ...                       ...             ...
# 10766              Timberland Pro                      J-AX        0.000000
# 10767  Timberwolves At New Jersey        Taking Back Sunday        0.000000
# 10768                I'LL BE GONE               Linkin Park        0.000000
# 10769                     Neptuin                   Annelie        0.000000
# 10770                 Marchin' On     The Smashing Pumpkins        0.000000
#
# ...

# %% [markdown]
# ## Some Interesting Plots

# %% [markdown]
# ### Months and times of the day when you listened to the most music

# %%
music_data.plot_yearly_minutes()

# %%
music_data.plot_monthly_minutes(year=2025)
